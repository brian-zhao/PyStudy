# %% [markdown]
# # Data Processing
#
# ### Big Data
# Large Datasets
# Technology
#
# ### What defines big data?
# * volume
# * Velocity
# * Variety
# ![Screen%20Shot%202021-11-07%20at%205.27.05%20pm.png](attachment:Screen%20Shot%202021-11-07%20at%205.27.05%20pm.png)
#
# ### Data Warehouses
# * Structured and/or processed
# * Ready to use
# * Rigid
# ### Data lakes
# * Raw and/or Unstructured
# * Ready to analyze
# * Flexible
#
# ### OLTP (online transctional processing) (Modify Database)
# * High volume of short transactions
# * Fast queries
# * High integrity
# ### OLAP (online analyticla processing) (Query database)
# * Low volumn of long running queires
# * agreegated historical data
# ### ETL (extract, transform, load) OLTP -> OLAP
#
# ### SQL (MySql, Postgresql)
# * columns and rows
# * relational database
#
# ### No SQL (Mongo, cassandra)
# * key value stores
# * json document stores

# %% [markdown]
# ### Batch vs Streaming
#
# ![Screen%20Shot%202021-11-07%20at%205.37.53%20pm.png](attachment:Screen%20Shot%202021-11-07%20at%205.37.53%20pm.png)

# %% [markdown]
# ## Data Processing Pipelines
#
# * Ingestion -> Storage -> Processing -> Visualization
#
# ### Ingestion
# - Archive Data
# - Log Collection
# - Device Data
# ### Processing
# - Extract Transfrom Load
# - Extract load transform
# - format
# - labeling
# - Filtering
# - Validating
#
# ### Visualization
# - dashboard

# %% [markdown]
# # Data Storage in GCP
#
# ![Screen%20Shot%202021-11-26%20at%208.56.51%20pm.png](attachment:Screen%20Shot%202021-11-26%20at%208.56.51%20pm.png)
#
# ## Cloud Storage
# - unstructured object storage
# - Reginal -dual-region
# - standard nearline or codeline
# - storage event triggers
#
# ## Cloud Bigtable
# - Petabyte-scale NoSQL database
# - High-throughput and scalability
# - Wide column key/value data
# - Time-series transactional IoT data
#
# ## BigQuery
# - Petabyte-scale analytics data warehouse
# - Fast SQL queries across large dataset
# - Fundations for BI and AI
# - Public datasets
#
# ## Cloud Spanner
# - Global SQL-based relational database
# - Horizontal scalability and high availability
# - Strong consistency
# - Financial transsaction
#
# ## Cloud SQL
# - Mysql postgeSQL instances
# - Built-in backups relicas and failover
# - Vertically Scalable
# - SQL Server
#
# ## Cloud Firestore
# - Fully Managed NoSQL document database
# - Large collections of small JSON documents
# - Realtime database with mobile SDKs
# - Strong consistency
#
# ## Cloud Memorystore
# - Managed Redis instances
# - In-memory DB, cache, or message broker
# - Built-in high availability
# - Vertically scalable

# %% [markdown]
# # Working with Data
#
# ### Managing Data
# - Sources and sinks
# - Structured and unstructured
# - Batched and streaming
#
# ### Data Modelling
# - Structured data requires a consistent model.
# - The model may already be in place.
# - Data may require preparation or transformation.
#
# - Conceptual
# - Logical
# - Physical
#
# ### Relational Data
# - Good relational schema design
# - Normalizaiton and reducing waste
# - Primary keys and table relationships
# - Accuracy and integrity
#
# ### Non-relational data
# - Simple key/value
# - Flexible document store
# - High volume columnar database
#
# ### Data Pipeline
# ![Screen%20Shot%202021-11-26%20at%209.13.28%20pm.png](attachment:Screen%20Shot%202021-11-26%20at%209.13.28%20pm.png)

# %% [markdown]
# # Google Cloud Storage = AWS S3
# - fully managed object storage
# - Multiple storage classes
# - Secure and durable
#
# - Bucket, projects
# - Bucket Region Dual Region Multi Regional
#
# ### Storage Classes
#  - Standard 0.02GB
#  - Nearline 30days 0.01GB 0.01GB retrieve
#  - Coldline 90days 0.004GB 0.02GB retrieve
#  - Archieve 365days 0.0012GB 0.05GB retrieve
#
# ### Objects
#  - opaque data
#  - immutable
#  - atomic
#  - verioned
#
# ###  Accessing buckets and objects
# - Google Cloud Console
# - Http API
# - SDKs
# - gsutil
#
# ### Advanced Features
# - Parallel uploads of composite objects
# - integrity checking
# - Transcoding
# - Requestor pays
#
# ### cost
# - operation charges
# - Network charges
# - Data retrieval charges
#
# ### Lifecycle Management
#
#
# ### Security and Access Control
# - IAM for bulk access to buckets
# - ACLs for granular access to buckets
# - Signed URLs
# - Signed policy documents
#
# ![Screen%20Shot%202021-11-26%20at%209.29.47%20pm.png](attachment:Screen%20Shot%202021-11-26%20at%209.29.47%20pm.png)
